# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statistics as stat
plt.rcParams["figure.figsize"]=[15,7]


x = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
y = np.array([6.194,6.179,5.362,5.867,3.022,5.215,5.088,5.111,6.544,4.765,4.754,2.581,3.3,2.86,3.233,4.571,5.136,4.146,4.273,5.336,5.583,5.049,5.209,4.369,4.971,2.478,3.302,2.567,4.603,6.547,5.392,4.98,1.57,5.332,3.631,7.473,5.839,4.52,4.876,5.064,5.202,6.865,5.376,4.727,3.342,2.16,6.592,4.868,2.14,5.427,6.111,2.598,5.415,4.034
])
df=pd.DataFrame(y,index=x)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2010")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2010, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(y),stat.mean(y),stat.variance(y)))
# Out:
# In the year 2010, the Standard deviation of birth rate in African countries was 1.339315151531667,the mean was 4.662018518518519 and the variance was 1.793765075122292

# %%
a = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
b= np.array([6.12,6.088,5.305,5.781,3.017,5.172,5.029,5.049,6.493,4.742,4.693,2.539,3.213,2.909,3.311,4.486,5.017,4.129,4.234,5.256,5.552,4.987,5.126,4.248,4.881,2.466,3.282,2.576,4.52,6.474,5.329,4.939,1.55,5.161,3.632,7.429,5.802,4.412,4.824,5.039,5.06,6.765,5.286,4.677,3.264,2.33,6.482,4.798,2.182,5.358,5.983,2.582,5.328,4.059])
df=pd.DataFrame(b,index=a)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2011")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2011, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(b),stat.mean(b),stat.variance(b)))
# Out:
# In the year 2011, the Standard deviation of birth rate in African countries was 1.3059989560621783,the mean was 4.610481481481481 and the variance was 1.7056332732354997

# %%
c = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
d= np.array([6.039,5.994,5.246,5.693,3.011,5.123,4.974,4.984,6.432,4.712,4.628,2.5,3.131,2.952,3.377,4.407,4.901,4.113,4.192,5.175,5.518,4.923,5.04,4.123,4.793,2.447,3.265,2.579,4.442,6.396,5.264,4.895,1.54,4.988,3.623,7.376,5.758,4.322,4.771,5.005,4.923,6.664,5.197,4.627,3.195,2.37,6.372,4.727,2.216,5.287,5.845,2.561,5.233,4.058])
df=pd.DataFrame(d,index=c)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2012")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2012, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(d),stat.mean(d),stat.variance(d)))
# Out:
# In the year 2012, the Standard deviation of birth rate in African countries was 1.2772619503443075,the mean was 4.5542037037037035 and the variance was 1.6313980897973444

# %%
e = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
f= np.array([5.953,5.897,5.183,5.606,3.002,5.068,4.92,4.916,6.363,4.676,4.561,2.463,3.054,2.99,3.421,4.335,4.787,4.098,4.146,5.094,5.48,4.855,4.952,3.999,4.706,2.423,3.25,2.571,4.369,6.315,5.198,4.847,1.44,4.821,3.604,7.314,5.709,4.251,4.715,4.96,4.793,6.563,5.108,4.577,3.139,2.26,6.262,4.656,2.24,5.215,5.699,2.537,5.132,4.03])
df=pd.DataFrame(f,index=e)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2013")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2013, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(f),stat.mean(f),stat.variance(f)))
# Out:
# In the year 2013, the Standard deviation of birth rate in African countries was 1.2583343400387492,the mean was 4.4911666666666665 and the variance was 1.5834053113207547

# %%
g = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
h= np.array([5.864,5.797,5.116,5.521,2.988,5.007,4.867,4.847,6.287,4.634,4.491,2.425,2.981,3.022,3.441,4.273,4.675,4.083,4.095,5.013,5.437,4.783,4.863,3.879,4.621,2.392,3.235,2.552,4.302,6.231,5.131,4.794,1.43,4.666,3.577,7.245,5.653,4.197,4.656,4.905,4.672,6.462,5.022,4.527,3.097,2.25,6.154,4.585,2.252,5.146,5.547,2.511,5.026,3.974])
df=pd.DataFrame(h,index=g)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2014")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2014, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(h),stat.mean(h),stat.variance(h)))
# Out:
# In the year 2014, the Standard deviation of birth rate in African countries was 1.2332627863839583,the mean was 4.429648148148148 and the variance was 1.520937100279525

# %%
i = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
j= np.array([5.774,5.697,5.047,5.436,2.968,4.941,4.813,4.777,6.203,4.587,4.419,2.385,2.912,3.043,3.436,4.217,4.565,4.064,4.041,4.933,5.39,4.708,4.774,3.765,4.54,2.356,3.218,2.524,4.241,6.145,5.062,4.738,1.36,4.527,3.54,7.169,5.592,4.157,4.594,4.841,4.561,6.363,4.937,4.477,3.065,2.31,6.049,4.516,2.251,5.079,5.394,2.484,4.918,3.896])
df=pd.DataFrame(j,index=i)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2015")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2015, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(j),stat.mean(j),stat.variance(j)))
# Out:
# In the year 2015, the Standard deviation of birth rate in African countries was 1.2102129729523503,the mean was 4.3666481481481485 and the variance was 1.4646154399021662

# %%
k = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
l= np.array([5.686,5.599,4.977,5.353,2.942,4.87,4.759,4.708,6.112,4.536,4.347,2.346,2.846,3.052,3.41,4.164,4.456,4.039,3.984,4.854,5.338,4.631,4.686,3.663,4.461,2.317,3.197,2.489,4.184,6.057,4.992,4.679,1.4,4.407,3.496,7.087,5.526,4.123,4.532,4.77,4.457,6.265,4.855,4.426,3.041,2.39,5.947,4.449,2.238,5.015,5.242,2.457,4.814,3.804])
df=pd.DataFrame(l,index=k)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2016")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2016, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(l),stat.mean(l),stat.variance(l)))
# Out:
# In the year 2016, the Standard deviation of birth rate in African countries was 1.1828961623437162,the mean was 4.305092592592593 and the variance was 1.3992433308874912

# %%
m = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
n= np.array([5.6,5.502,4.906,5.271,2.91,4.796,4.704,4.639,6.017,4.482,4.275,2.309,2.785,3.045,3.37,4.112,4.35,4.008,3.926,4.777,5.281,4.553,4.599,3.572,4.387,2.277,3.171,2.451,4.13,5.968,4.922,4.619,1.44,4.302,3.447,7.001,5.457,4.088,4.469,4.697,4.359,6.168,4.775,4.374,3.018,2.41,5.846,4.384,2.219,4.953,5.095,2.43,4.718,3.707])
df=pd.DataFrame(n,index=m)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2017")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2017, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(n),stat.mean(n),stat.variance(n)))
# Out:
# In the year 2017, the Standard deviation of birth rate in African countries was 1.1586582906928147,the mean was 4.242055555555556 and the variance was 1.342489034591195

# %%
o = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
p= np.array([5.519,5.41,4.836,5.189,2.874,4.721,4.649,4.572,5.919,4.428,4.205,2.274,2.728,3.023,3.326,4.056,4.247,3.969,3.87,4.7,5.219,4.476,4.513,3.492,4.315,2.24,3.141,2.415,4.077,5.877,4.852,4.561,1.41,4.209,3.396,6.913,5.387,4.044,4.407,4.625,4.263,6.072,4.696,4.321,2.99,2.41,5.747,4.32,2.197,4.892,4.955,2.405,4.633,3.615])
df=pd.DataFrame(p,index=o)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2018")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2018, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(p),stat.mean(p),stat.variance(p)))
# Out:
# In the year 2018, the Standard deviation of birth rate in African countries was 1.1390292070843464,the mean was 4.177777777777778 and the variance was 1.297387534591195

# %%
q = np.array(["Angola","Burundi","Benin","Burkina", "Botswana", "Central African Republic", "Ivory Coast", "Cameroon","Congo", "Congo, Democratic Republic of","Comoros","Cape Verde","Djibouti", "Algeria", "Egypt","Eritrea", "Ethiopia", "Gabon","Ghana", "Guinea","Gambia",  "Guinea-Bissau","Equatorial Guinea",  "Kenya","Liberia", "Libya","Lesotho","Morocco","Madagascar","Mali","Mozambique", "Mauritania","Mauritius","Malawi","Namibia", "Niger", "Nigeria", "Rwanda","Sudan","Senegal","Sierra Leone","Somalia","South Sudan","Sao Tome and Principe","Swaziland","Seychelles","Chad","Togo", "ettTunisia","Tanzania",  "Uganda","South Africa","Zambia", "Zimbabwe"])
r= np.array([5.442,5.321,4.767,5.109,2.836,4.645,4.593,4.506,5.819,4.374,4.138,2.242,2.676,2.988,3.28,3.997,4.146,3.922,3.816,4.625,5.154,4.402,4.429,3.423,4.247,2.206,3.108,2.382,4.026,5.785,4.783,4.503,1.4,4.127,3.344,6.824,5.317,3.99,4.347,4.556,4.169,5.978,4.619,4.267,2.958,2.34,5.649,4.259,2.174,4.832,4.824,2.381,4.559,3.531])
df=pd.DataFrame(r,index=q)
df=df.rename(columns={0:"Birthrate"})
df=df.sort_values("Birthrate", ascending=False)

df.plot(kind="bar",width=0.3,color="red" )
plt.title("Birth rate per woman in African countries in the year 2019")
plt.xlabel("Countries")
plt.ylabel("Birthrate")
txt="In the year 2019, the Standard deviation of birth rate in African countries was {0},the mean was {1} and the variance was {2}"
print ( txt.format(stat.stdev(r),stat.mean(r),stat.variance(r)))
# Out:
# In the year 2019, the Standard deviation of birth rate in African countries was 1.1211007800904862,the mean was 4.113611111111111 and the variance was 1.2568669591194968
